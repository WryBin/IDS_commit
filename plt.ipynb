# %%
# 绘制
import pandas as pd
result = pd.read_csv("result/result.csv")
result_local = pd.read_csv("result/result_local.csv")

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20, 10))
plt.plot(result['Steam_flow'])
plt.plot(result_local['Steam_flow'])
